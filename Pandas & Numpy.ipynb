# %%
import pandas as pd

# %%
cvs_file1 = "example.csv"
df = pd.read_csv(cvs_file1)
df
# Out:
#        id first_name      last_name                           email  gender  \
# 0       1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1       2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2       3      Nanni         Herity        nherity2@statcounter.com  Female
# 3       4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4       5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
# ..    ...        ...            ...                             ...     ...
# 995   996   Parrnell           Jeff             pjeffrn@4shared.com    Male
# 996   997        Pat       Warstall         pwarstallro@dropbox.com    Male
# 997   998     Willyt     Vannuccini     wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan     Petrashkov     gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling       Francesc     sfrancescrr@cyberchimps.com    Male
#
#          ip_address                   city
# ...

# %%
pwd
# Out:
# 'C:\\Users\\jigga'

# %%
df.iloc[2,3]
# Out:
# 'nherity2@statcounter.com'

# %%
new_df1 = df.loc[(df['gender']=='Male'),['first_name','last_name']]

# %%
new_df1
# Out:
#     first_name   last_name
# 0       Joseph   Zaniolini
# 3       Orazio    Frayling
# 8      Chrissy    Hedworth
# 9        Hyatt   Gasquoine
# 11      Andrew        Bath
# ..         ...         ...
# 994      Glynn    Wakerley
# 995   Parrnell        Jeff
# 996        Pat    Warstall
# 998     Gaelan  Petrashkov
# 999   Stirling    Francesc
#
# [486 rows x 2 columns]

# %%
df
# Out:
#        id first_name      last_name                           email  gender  \
# 0       1     Joseph      Zaniolini  jzaniolini0@simplemachines.org    Male
# 1       2     Freida  Drillingcourt       fdrillingcourt1@umich.edu  Female
# 2       3      Nanni         Herity        nherity2@statcounter.com  Female
# 3       4     Orazio       Frayling        ofrayling3@economist.com    Male
# 4       5   Julianne       Murrison         jmurrison4@cbslocal.com  Female
# ..    ...        ...            ...                             ...     ...
# 995   996   Parrnell           Jeff             pjeffrn@4shared.com    Male
# 996   997        Pat       Warstall         pwarstallro@dropbox.com    Male
# 997   998     Willyt     Vannuccini     wvannuccinirp@tuttocitta.it  Female
# 998   999     Gaelan     Petrashkov     gpetrashkovrq@hostgator.com    Male
# 999  1000   Stirling       Francesc     sfrancescrr@cyberchimps.com    Male
#
#          ip_address                   city
# ...

# %%
df.loc[(df['last_name']=='Petrashkov'),['first_name','ip_address','city']]
# Out:
#     first_name      ip_address       city
# 998     Gaelan  219.109.169.75  Bethlehem

# %%
df1 = df[df['gender']=='Male']

# %%
df1.to_csv("new_panda_test_file.csv")

# %%
import csv

with open("new_panda_test_file.csv",encoding="utf-8") as f1:
    reading = csv.reader(f1)
    readlines = list(reading)

for line in readlines:
    print(line)
# Out:
# ['', 'id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city']
# ['0', '1', 'Joseph', 'Zaniolini', 'jzaniolini0@simplemachines.org', 'Male', '163.168.68.132', 'Pedro Leopoldo']
# ['3', '4', 'Orazio', 'Frayling', 'ofrayling3@economist.com', 'Male', '25.199.143.143', 'Kungur']
# ['8', '9', 'Chrissy', 'Hedworth', 'chedworth8@china.com.cn', 'Male', '124.222.93.57', 'Boevange-sur-Attert']
# ['9', '10', 'Hyatt', 'Gasquoine', 'hgasquoine9@google.ru', 'Male', '221.155.106.39', 'Złoty Stok']
# ['11', '12', 'Andrew', 'Bath', 'abathb@umn.edu', 'Male', '64.36.30.186', 'El Hermel']
# ['12', '13', 'Lucais', 'Chastang', 'lchastangc@goo.gl', 'Male', '142.182.6.86', 'Tilburg']
# ['13', '14', 'Car', 'Cerie', 'cceried@yale.edu', 'Male', '203.204.69.107', 'Shofirkon']
# ['15', '16', 'Prescott', 'Caldeiro', 'pcaldeirof@chronoengine.com', 'Male', '29.81.197.109', 'Patzicía']
# ['17', '18', 'Kalvin', 'Rois', 'kroish@unicef.org', 'Male', '75.20.57.166', 'Marsh Harbour']
# ...

# %%
list_name = df['first_name'].unique()
list_name
# Out:
# array(['Joseph', 'Freida', 'Nanni', 'Orazio', 'Julianne', 'Lucy', 'Dyana',
#        'Kassey', 'Chrissy', 'Hyatt', 'Felicdad', 'Andrew', 'Lucais',
#        'Car', 'Alvera', 'Prescott', 'Nariko', 'Kalvin', 'Isa',
#        'Benedetta', 'Poul', 'Virgie', 'Gillie', 'Tabor', 'Sarina',
#        'Elbert', 'Danita', 'Jone', 'Merralee', 'Charyl', 'Giuseppe',
#        'Sutherlan', 'Alexander', 'Blayne', 'Alfredo', 'Harman', 'Haslett',
#        'Jeanelle', 'Hetty', 'Elmira', 'Granger', 'Tobie', 'Knox', 'Eliot',
#        'Honey', 'Karmen', 'Fairleigh', 'Angelina', 'Lilla', 'Penn',
#        'Salvidor', 'Ker', 'Lorne', 'Elijah', 'Paxton', 'Ernie', 'Deb',
#        'Morna', 'Gregorius', 'Raynard', 'Harrietta', 'Cariotta',
#        'Lisetta', 'Danielle', 'Ingra', 'Ferdinand', 'Salomi', 'Lurlene',
#        'Penni', 'Stormie', 'Baily', 'Kristofor', 'Cherey', 'Phillip',
#        'Karil', 'Loise', 'Rickie', 'Orella', 'Calli', 'Harli', 'Edvard',
# ...

# %%
len(list_name)
# Out:
# 934

# %%
import numpy as np

# %%
a = np.array([1,3,7])

# %%
a
# Out:
# array([1, 3, 7])

# %%
a.size
# Out:
# 3

# %%
a.ndim
# Out:
# 1

# %%
b = np.array([2,8,"q"])

# %%
b
# Out:
# array(['2', '8', 'q'], dtype='<U11')

# %%
b[2]=5

# %%
b
# Out:
# array(['2', '8', '5'], dtype='<U11')

# %%
type(b)
# Out:
# numpy.ndarray

# %%
b.dtype
# Out:
# dtype('<U11')

# %%
a.dtype
# Out:
# dtype('int32')

# %%
a.shape
# Out:
# (3,)

# %%
int(3.2)
# Out:
# 3
